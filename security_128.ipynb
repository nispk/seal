# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
dataframe_ckks = pd.read_csv(r'C:\Users\npkal\Desktop\SEAL_N\SEAL-master\bin\ckks\sec_level_128.csv')

# %%
dataframe_bfv = pd.read_csv(r'C:\Users\npkal\Desktop\SEAL_N\SEAL-master\bin\bfv\sec_level_128.csv')

# %%
labels = ['4096', '8192', '16384', '32768']
labels = ['4096', '8192', '16384', '32768']
encode_time_ckks = dataframe_ckks.avg_encode_ckks
batchencode_time_bfv = dataframe_bfv.avg_batch_bfv

# %%
x = np.arange(len(labels))
fig,ax = plt.subplots()
width = 0.35
rects1= ax.bar(x - width/2 , encode_time_ckks, width, label = 'ckks')
rects2= ax.bar(x + width/2 , batchencode_time_bfv, width, label = 'bfv')

ax.set_ylabel('Time(µs)')
ax.set_xlabel('Polynomial modulus degree')
ax.set_title('Encoding with security level 128 bits')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                   xy=(rect.get_x() + rect.get_width() / 2, height),
                   xytext =(0,3),
                   textcoords = "offset points",
                   ha = 'center', va = 'bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.show()
fig.savefig('sec_128N\encode.png')

# %%
decode_time_ckks = dataframe_ckks.avg_decode_ckks
batchdecode_time_bfv = dataframe_bfv.avg_unbatch_bfv

# %%
x = np.arange(len(labels))
fig,ax = plt.subplots()
width = 0.35
rects1= ax.bar(x - width/2 , decode_time_ckks, width, label = 'ckks')
rects2= ax.bar(x + width/2 , batchdecode_time_bfv, width, label = 'bfv')

ax.set_ylabel('Time(µs)')
ax.set_xlabel('Polynomial modulus degree')
ax.set_title('Decoding with security level 128 bits')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                   xy=(rect.get_x() + rect.get_width() / 2, height),
                   xytext =(0,3),
                   textcoords = "offset points",
                   ha = 'center', va = 'bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.show()
fig.savefig('sec_128N\Decode.png')

# %%
encrypt_time_ckks = dataframe_ckks.avg_encrypt_ckks
encrypt_time_bfv = dataframe_bfv.avg_encrypt_bfv

# %%
x = np.arange(len(labels))
fig,ax = plt.subplots()
width = 0.35
rects1= ax.bar(x - width/2 , encrypt_time_ckks, width, label = 'ckks')
rects2= ax.bar(x + width/2 , encrypt_time_bfv, width, label = 'bfv')

ax.set_ylabel('Time(µs)')
ax.set_xlabel('Polynomial modulus degree')
ax.set_title('Encryption with security level 128 bits')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                   xy=(rect.get_x() + rect.get_width() / 2, height),
                   xytext =(0,3),
                   textcoords = "offset points",
                   ha = 'center', va = 'bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.show()
fig.savefig('sec_128N\Encrypt.png')

# %%
decrypt_time_ckks = dataframe_ckks.avg_decrypt_ckks
decrypt_time_bfv = dataframe_bfv.avg_decrypt_bfv

# %%
x = np.arange(len(labels))
fig,ax = plt.subplots()
width = 0.35
rects1= ax.bar(x - width/2 , decrypt_time_ckks, width, label = 'ckks')
rects2= ax.bar(x + width/2 , decrypt_time_bfv, width, label = 'bfv')

ax.set_ylabel('Time(µs)')
ax.set_xlabel('Polynomial modulus degree')
ax.set_title('Decryption with security level 128 bits')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                   xy=(rect.get_x() + rect.get_width() / 2, height),
                   xytext =(0,3),
                   textcoords = "offset points",
                   ha = 'center', va = 'bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.show()
fig.savefig('sec_128N\Decrypt.png')

# %%
add_time_ckks = dataframe_ckks.avg_add_ckks
add_time_bfv = dataframe_bfv.avg_add_bfv

# %%
x = np.arange(len(labels))
fig,ax = plt.subplots()
width = 0.35
rects1= ax.bar(x - width/2 , add_time_ckks, width, label = 'ckks')
rects2= ax.bar(x + width/2 , add_time_bfv, width, label = 'bfv')

ax.set_ylabel('Time(µs)')
ax.set_xlabel('Polynomial modulus degree')
ax.set_title('Add operation with security level 128 bits')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                   xy=(rect.get_x() + rect.get_width() / 2, height),
                   xytext =(0,3),
                   textcoords = "offset points",
                   ha = 'center', va = 'bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.show()
fig.savefig('sec_128N\Add.png')

# %%
mult_time_ckks = dataframe_ckks.avg_multiply_ckks
mult_time_bfv = dataframe_bfv.avg_multiply_bfv

# %%
x = np.arange(len(labels))
fig,ax = plt.subplots()
width = 0.35
rects1= ax.bar(x - width/2 , mult_time_ckks, width, label = 'ckks')
rects2= ax.bar(x + width/2 , mult_time_bfv, width, label = 'bfv')

ax.set_ylabel('Time(µs)')
ax.set_xlabel('Polynomial modulus degree')
ax.set_title('Multiply operation with security level 128 bits')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                   xy=(rect.get_x() + rect.get_width() / 2, height),
                   xytext =(0,3),
                   textcoords = "offset points",
                   ha = 'center', va = 'bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.show()
fig.savefig('sec_128N\Multiply.png')

# %%
mult_plain_time_ckks = dataframe_ckks.avg_multiply_plain_ckks
mult_plain_time_bfv = dataframe_bfv.avg_multiply_plain_bfv

# %%
x = np.arange(len(labels))
fig,ax = plt.subplots()
width = 0.35
rects1= ax.bar(x - width/2 , mult_plain_time_ckks, width, label = 'ckks')
rects2= ax.bar(x + width/2 , mult_plain_time_bfv, width, label = 'bfv')

ax.set_ylabel('Time(µs)')
ax.set_xlabel('Polynomial modulus degree')
ax.set_title('Multiply_plain operation with security level 128 bits')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                   xy=(rect.get_x() + rect.get_width() / 2, height),
                   xytext =(0,3),
                   textcoords = "offset points",
                   ha = 'center', va = 'bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.show()
fig.savefig('sec_128N\Multiply_plain.png')

# %%
square_time_ckks = dataframe_ckks.avg_square_ckks
square_time_bfv = dataframe_bfv.avg_square_bfv

# %%
x = np.arange(len(labels))
fig,ax = plt.subplots()
width = 0.35
rects1= ax.bar(x - width/2 , square_time_ckks, width, label = 'ckks')
rects2= ax.bar(x + width/2 , square_time_bfv, width, label = 'bfv')

ax.set_ylabel('Time(µs)')
ax.set_xlabel('Polynomial modulus degree')
ax.set_title('Square operation with security level 128 bits')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                   xy=(rect.get_x() + rect.get_width() / 2, height),
                   xytext =(0,3),
                   textcoords = "offset points",
                   ha = 'center', va = 'bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.show()
fig.savefig('sec_128N\square.png')

# %%
relinearize_time_ckks = dataframe_ckks.avg_relinearize_ckks
relinearize_time_bfv = dataframe_bfv.avg_relenearize_bfv

# %%
x = np.arange(len(labels))
fig,ax = plt.subplots()
width = 0.35
rects1= ax.bar(x - width/2 , relinearize_time_ckks, width, label = 'ckks')
rects2= ax.bar(x + width/2 , relinearize_time_bfv, width, label = 'bfv')

ax.set_ylabel('Time(µs)')
ax.set_xlabel('Polynomial modulus degree')
ax.set_title('Relinearization with security level 128 bits')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                   xy=(rect.get_x() + rect.get_width() / 2, height),
                   xytext =(0,3),
                   textcoords = "offset points",
                   ha = 'center', va = 'bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.show()
fig.savefig('sec_128N\Relinearize.png')

# %%
rotate1_time_ckks = dataframe_ckks.avg_rotate_one_step_ckks
rotate1_time_bfv = dataframe_bfv.avg_rotate_rows_one_step_bfv

# %%
x = np.arange(len(labels))
fig,ax = plt.subplots()
width = 0.35
rects1= ax.bar(x - width/2 , rotate1_time_ckks, width, label = 'ckks')
rects2= ax.bar(x + width/2 , rotate1_time_bfv, width, label = 'bfv')

ax.set_ylabel('Time(µs)')
ax.set_xlabel('Polynomial modulus degree')
ax.set_title('Rotate 1 step with security level 128 bits')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                   xy=(rect.get_x() + rect.get_width() / 2, height),
                   xytext =(0,3),
                   textcoords = "offset points",
                   ha = 'center', va = 'bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.show()
fig.savefig('sec_128N\Rotate1step.png')

# %%
rotate_rand_time_ckks = dataframe_ckks.avg_rotate_random_ckks
rotate_rand_time_bfv = dataframe_bfv.avg_rotate_rows_random_bfv

# %%
x = np.arange(len(labels))
fig,ax = plt.subplots()
width = 0.35
rects1= ax.bar(x - width/2 , rotate_rand_time_ckks, width, label = 'ckks')
rects2= ax.bar(x + width/2 , rotate_rand_time_bfv, width, label = 'bfv')

ax.set_ylabel('Time(µs)')
ax.set_xlabel('Polynomial modulus degree')
ax.set_title('Rotate random with security level 128 bits')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                   xy=(rect.get_x() + rect.get_width() / 2, height),
                   xytext =(0,3),
                   textcoords = "offset points",
                   ha = 'center', va = 'bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.show()
fig.savefig('sec_128N\Rotate_random.png')
